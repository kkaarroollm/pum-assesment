# %% [markdown]
# ### NYC Airbnb Prediction - Data Extraction
#
# - [NYC Airbnb Open Data](https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data)
# - [MTA Subway Stations](https://catalog.data.gov/dataset/mta-subway-stations)

# %%
from pathlib import Path

import pandas as pd

pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", "{:.4f}".format)

# %% [markdown]
# ### NYC Airbnb Open Data

# %%
airbnb_path = Path("../data/raw/AB_NYC_2019.csv")
airbnb_df = pd.read_csv(airbnb_path)

airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington   40.6475   -73.9724
# 1     Jennifer           Manhattan       Midtown   40.7536   -73.9838
# 2    Elisabeth           Manhattan        Harlem   40.8090   -73.9419
# 3  LisaRoxanne            Brooklyn  Clinton Hill   40.6851   -73.9598
# 4        Laura           Manhattan   East Harlem   40.7985   -73.9440
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb_df.shape
# Out:
# (48895, 16)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb_df.describe(include="all").T
# Out:
#                                     count unique              top   freq  \
# id                             48895.0000    NaN              NaN    NaN
# name                                48879  47905   Hillside Hotel     18
# host_id                        48895.0000    NaN              NaN    NaN
# host_name                           48874  11452          Michael    417
# neighbourhood_group                 48895      5        Manhattan  21661
# neighbourhood                       48895    221     Williamsburg   3920
# latitude                       48895.0000    NaN              NaN    NaN
# longitude                      48895.0000    NaN              NaN    NaN
# room_type                           48895      3  Entire home/apt  25409
# price                          48895.0000    NaN              NaN    NaN
# minimum_nights                 48895.0000    NaN              NaN    NaN
# number_of_reviews              48895.0000    NaN              NaN    NaN
# ...

# %% [markdown]
# ### MTA Subway Stations

# %%
mta_stations_path = Path("../data/external/MTA_Subway_Stations.csv")
mta_stations_df = pd.read_csv(mta_stations_path)
mta_stations_df.head()
# Out:
#   GTFS Stop ID  Station ID  Complex ID Division              Line  \
# 0          127         317         611      IRT    Broadway - 7Av
# 1          S17         515         515      SIR     Staten Island
# 2          S01         139         627      BMT  Franklin Shuttle
# 3          254         349         349      IRT       Eastern Pky
# 4          M01         108         108      BMT         Myrtle Av
#
#                         Stop Name Borough    CBD Daytime Routes Structure  \
# 0                  Times Sq-42 St       M   True          1 2 3    Subway
# 1                        Annadale      SI  False            SIR  Open Cut
# 2                     Franklin Av      Bk  False              S  Elevated
# 3                       Junius St      Bk  False              3  Elevated
# 4  Middle Village-Metropolitan Av       Q  False              M  Elevated
#
#    GTFS Latitude  GTFS Longitude North Direction Label South Direction Label  \
# ...

# %%
mta_stations_df.shape
# Out:
# (496, 19)

# %%
mta_stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GTFS Stop ID           496 non-null    object
#  1   Station ID             496 non-null    int64
#  2   Complex ID             496 non-null    int64
#  3   Division               496 non-null    object
#  4   Line                   496 non-null    object
#  5   Stop Name              496 non-null    object
#  6   Borough                496 non-null    object
#  7   CBD                    496 non-null    bool
#  8   Daytime Routes         496 non-null    object
#  9   Structure              496 non-null    object
#  10  GTFS Latitude          496 non-null    float64
#  11  GTFS Longitude         496 non-null    float64
#  12  North Direction Label  496 non-null    object
#  13  South Direction Label  496 non-null    object
# ...
